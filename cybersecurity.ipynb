# %% [raw]
# cybersecurity

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\bharath s\Downloads\cybersecurity_dataset (1).csv")
df
# Out:
#                 Timestamp       IP_Address Threat_Level    Attack_Type  \
# 0     2024-01-01 00:00:00  192.168.180.175         High        Malware
# 1                     NaN  192.168.235.227     Critical           DDoS
# 2     2024-01-01 02:00:00    192.168.4.189          Low        Malware
# 3     2024-01-01 03:00:00   192.168.177.56         High       Phishing
# 4     2024-01-01 04:00:00  192.168.191.154         High        Malware
# ...                   ...              ...          ...            ...
# 8995                  NaN   192.168.255.97     Critical     Ransomware
# 8996  2025-01-09 20:00:00              NaN          NaN  SQL Injection
# 8997  2025-01-09 21:00:00  192.168.117.218       Medium           DDoS
# 8998  2025-01-09 22:00:00    192.168.21.24          Low     Ransomware
# 8999                  NaN  192.168.135.189     Critical        Malware
#
#      Affected_System  Response_Time         Status Data_Compromised  \
# ...

# %%
df.head()
# Out:
#              Timestamp       IP_Address Threat_Level Attack_Type  \
# 0  2024-01-01 00:00:00  192.168.180.175         High     Malware
# 1                  NaN  192.168.235.227     Critical        DDoS
# 2  2024-01-01 02:00:00    192.168.4.189          Low     Malware
# 3  2024-01-01 03:00:00   192.168.177.56         High    Phishing
# 4  2024-01-01 04:00:00  192.168.191.154         High     Malware
#
#   Affected_System  Response_Time         Status Data_Compromised Security_Team
# 0     Application         1995.0  Investigating               No           NaN
# 1     Application          780.0        Pending               No           NaN
# 2             IoT          247.0       Resolved              Yes           SOC
# 3           Cloud         3327.0        Pending              Yes            IT
# 4             NaN         2402.0        Pending               No            IT

# %%
df.tail()
# Out:
#                 Timestamp       IP_Address Threat_Level    Attack_Type  \
# 8995                  NaN   192.168.255.97     Critical     Ransomware
# 8996  2025-01-09 20:00:00              NaN          NaN  SQL Injection
# 8997  2025-01-09 21:00:00  192.168.117.218       Medium           DDoS
# 8998  2025-01-09 22:00:00    192.168.21.24          Low     Ransomware
# 8999                  NaN  192.168.135.189     Critical        Malware
#
#      Affected_System  Response_Time         Status Data_Compromised  \
# 8995        Database         2194.0  Investigating              Yes
# 8996             NaN         1452.0        Pending              NaN
# 8997             NaN         2252.0       Resolved              Yes
# 8998        Database         1128.0  Investigating              Yes
# 8999           Cloud         1523.0  Investigating               No
#
#             Security_Team
# 8995                  NaN
# 8996                  SOC
# 8997                  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Timestamp         8100 non-null   object
#  1   IP_Address        8100 non-null   object
#  2   Threat_Level      8100 non-null   object
#  3   Attack_Type       8100 non-null   object
#  4   Affected_System   8100 non-null   object
#  5   Response_Time     8100 non-null   float64
#  6   Status            8100 non-null   object
#  7   Data_Compromised  8100 non-null   object
#  8   Security_Team     8100 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 632.9+ KB

# %%
df.shape
# Out:
# (9000, 9)

# %%
df.isnull().sum()
# Out:
# Timestamp           900
# IP_Address          900
# Threat_Level        900
# Attack_Type         900
# Affected_System     900
# Response_Time       900
# Status              900
# Data_Compromised    900
# Security_Team       900
# dtype: int64

# %%
df.drop(['IP_Address'],axis=1,inplace=True)

# %%
df.drop(['Timestamp'],axis=1,inplace=True)

# %%
df.drop(['Threat_Level'],axis=1,inplace=True)

# %%
df.drop(['Attack_Type'],axis=1,inplace=True)

# %%
df.drop(['Affected_System'],axis=1,inplace=True)

# %%
df.drop(['Response_Time'],axis=1,inplace=True)

# %%
df.drop(['Status'],axis=1,inplace=True)

# %%
df.drop(['Data_Compromised'],axis=1,inplace=True)

# %%
df.drop(['Security_Team'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Threat_Numeric    2883
# dtype: int64

# %%
df.drop(['Threat_Numeric'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [raw]
#  Convert Timestamp to datetime

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

# %% [raw]
# Distribution of Threat Levels

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Threat_Level', order=df['Threat_Level'].value_counts().index, palette='coolwarm')
plt.title('Threat Level Distribution')
plt.show()
# Out:
# C:\Users\bharath s\AppData\Local\Temp\ipykernel_25524\1522967096.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Threat_Level', order=df['Threat_Level'].value_counts().index, palette='coolwarm')

# %% [raw]
# Most Common Attack Types

# %%
plt.figure(figsize=(8, 4))
sns.countplot(y=df['Attack_Type'], order=df['Attack_Type'].value_counts().index, palette='viridis')
plt.title('Most Common Attack Types')
plt.show()
# Out:
# C:\Users\bharath s\AppData\Local\Temp\ipykernel_25524\2727731600.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Attack_Type'], order=df['Attack_Type'].value_counts().index, palette='viridis')

# %% [raw]
# Response Time by Threat Level

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Threat_Level', y='Response_Time', palette='coolwarm')
plt.title('Response Time by Threat Level')
plt.show()
# Out:
# C:\Users\bharath s\AppData\Local\Temp\ipykernel_25524\3260854144.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Threat_Level', y='Response_Time', palette='coolwarm')

# %% [raw]
# Most Attacked System Type

# %%
plt.figure(figsize=(6, 4))
sns.countplot(y=df['Affected_System'], order=df['Affected_System'].value_counts().index, palette='Blues')
plt.title('Most Attacked System Types')
plt.show()
# Out:
# C:\Users\bharath s\AppData\Local\Temp\ipykernel_25524\29600631.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Affected_System'], order=df['Affected_System'].value_counts().index, palette='Blues')

# %% [raw]
# Incidents per Security Team

# %%
df['Security_Team'].value_counts().plot(kind='bar', color='purple')
plt.title('Incidents per Security Team')
plt.show()

# %% [raw]
#  Average Response Time by Attack Type

# %%
avg_response = df.groupby('Attack_Type')['Response_Time'].mean().sort_values()
avg_response.plot(kind='barh', color='red')
plt.title('Average Response Time by Attack Type')
plt.show()

# %% [raw]
# Proportion of Data Compromised

# %%
df['Data_Compromised'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['green', 'red'])
plt.title('Data Compromised Proportion')
plt.show()

# %% [raw]
# Status Distribution

# %%
sns.countplot(data=df, x='Status', palette='pastel')
plt.title('Incident Status Distribution')
plt.show()
# Out:
# C:\Users\bharath s\AppData\Local\Temp\ipykernel_25524\812285561.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Status', palette='pastel')

# %% [raw]
# Most Frequent IP Addresses

# %%
top_ips = df['IP_Address'].value_counts().nlargest(10)
top_ips.plot(kind='bar', color='orange')
plt.title('Top 10 Frequent IP Addresses')
plt.show()

# %% [raw]
# Correlation Between Response Time and Threat Level

# %%
df['Threat_Numeric'] = df['Threat_Level'].map({'Low': 1, 'High': 2, 'Critical': 3})
plt.figure(figsize=(6, 4))
sns.heatmap(df[['Response_Time', 'Threat_Numeric']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Between Response Time and Threat Level')
plt.show()

# %% [raw]
# Incidents per Day

# %%
df.set_index('Timestamp').resample('D').size().plot(title='Incidents Per Day', color='blue')
plt.show()

# %% [raw]
# Percentage of Critical Threats

# %%
critical_percent = (df['Threat_Level'] == 'Critical').mean() * 100
print(f'Critical threats percentage: {critical_percent:.2f}%')
# Out:
# Critical threats percentage: 22.71%

# %% [raw]
# Avg Response Time by Security Team

# %%
avg_team_response = df.groupby('Security_Team')['Response_Time'].mean()
avg_team_response.plot(kind='bar', color='cyan')
plt.title('Average Response Time by Security Team')
plt.show()

# %% [raw]
# Incidents Per Month

# %%
df['Month'] = df['Timestamp'].dt.month
df['Month'].value_counts().sort_index().plot(kind='bar', color='magenta')
plt.title('Incidents Per Month')
plt.show()
